# %%
import time
import random 
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# 487820 through 487825 are valid pages<br>
# 487826 is a 404

# %%
url_base = "https://archiveofourown.org/works/"
current_ix =  487820
streak_404_cnt = 0

# %% [markdown]
# ### Testing Basic Request Loop

# %%
current_ix =  487820

for x in range(0,7):
    url = url_base + str(current_ix)
    current_ix+=1
    page = requests.get(url)
    print(page)
    wait_time = round(random.uniform(1,3), 2)
    time.sleep(wait_time)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [404]>

# %%
page.status_code
# Out:
# 200

# %%
if page.status_code == 404:
    streak_404_cnt +=1

# %%
if page:
    print('A simple Boolean testing message also works')
# Out:
# A simple Boolean testing message also works

# %%
else:
    other_error_cnt +=1

# %% [markdown]
# ### Exploring HTML and Determing Correct Tags

# %%
url_base = "https://archiveofourown.org/works/"
current_ix =  487820
url = url_base + str(current_ix)
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# soup

# %%
results = soup.find(id = "main")

# %%
downloads = results.find_all('ul', class_ = 'expandable secondary')

# %%
downloads = results.find('ul', class_ = 'expandable secondary')

# %%
downloads
# Out:
# <ul class="expandable secondary">
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.azw3?updated_at=1387518470">AZW3</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.epub?updated_at=1387518470">EPUB</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.mobi?updated_at=1387518470">MOBI</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.pdf?updated_at=1387518470">PDF</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.html?updated_at=1387518470">HTML</a></li>
# </ul>

# %%
downloads.get_attribute_list('ul')
# Out:
# [None]

# %%
downloads.get_text()
# Out:
# '\nAZW3\nEPUB\nMOBI\nPDF\nHTML\n'

# %%
len('<li><a href="')
# Out:
# 13

# %%
str(downloads[0]).split('\n')[i][13:-9].split('">')
# Out:
# ['/downloads/487820/All%20of%20time%20and%20space.pdf?updated_at=1387518470',
#  'PDF']

# %%
for i in range(1,6):
    print(str(downloads[0]).split('\n')[i][13:-9].split('">'))
# Out:
# ['/downloads/487820/All%20of%20time%20and%20space.azw3?updated_at=1387518470', 'AZW3']
# ['/downloads/487820/All%20of%20time%20and%20space.epub?updated_at=1387518470', 'EPUB']
# ['/downloads/487820/All%20of%20time%20and%20space.mobi?updated_at=1387518470', 'MOBI']
# ['/downloads/487820/All%20of%20time%20and%20space.pdf?updated_at=1387518470', 'PDF']
# ['/downloads/487820/All%20of%20time%20and%20space.html?updated_at=1387518470', 'HTML']

# %% [markdown]
# ^ that some ugly ass code, but it does the trick

# %%
test = results.find_all('a', class_ = 'tag')
print(test)
# Out:
# [<a class="tag" href="/tags/Teen%20And%20Up%20Audiences/works">Teen And Up Audiences</a>, <a class="tag" href="/tags/No%20Archive%20Warnings%20Apply/works">No Archive Warnings Apply</a>, <a class="tag" href="/tags/Multi/works">Multi</a>, <a class="tag" href="/tags/Doctor%20Who%20(2005)/works">Doctor Who (2005)</a>, <a class="tag" href="/tags/Eleventh%20Doctor*s*Jack%20Harkness*s*River%20Song/works">Eleventh Doctor/Jack Harkness/River Song</a>, <a class="tag" href="/tags/Amy%20Pond*s*Rory%20Williams/works">Amy Pond/Rory Williams</a>, <a class="tag" href="/tags/Jack%20Harkness/works">Jack Harkness</a>, <a class="tag" href="/tags/Eleventh%20Doctor/works">Eleventh Doctor</a>, <a class="tag" href="/tags/River%20Song/works">River Song</a>, <a class="tag" href="/tags/Amy%20Pond/works">Amy Pond</a>, <a class="tag" href="/tags/Rory%20Williams/works">Rory Williams</a>]

# %%
print(test[0].get_text())
# Out:
# Teen And Up Audiences

# %%
print(test[5].get_text())
# Out:
# Amy Pond/Rory Williams

# %%
len(test)
# Out:
# 11

# %%
for x in range(len(test)):
    print(test[x].get_text())
# Out:
# Teen And Up Audiences
# No Archive Warnings Apply
# Multi
# Doctor Who (2005)
# Eleventh Doctor/Jack Harkness/River Song
# Amy Pond/Rory Williams
# Jack Harkness
# Eleventh Doctor
# River Song
# Amy Pond
# Rory Williams

# %%
test.get_text()
# Out:
# 'Teen And Up Audiences'

# %%
test = results.find('a', class_ = 'tag')
print(test)

# %%
test.get_text()

# %%
test = results.find_all('ul', class_ = 'commas')

# %%
print(test[0].get_text())
# Out:
# Teen And Up Audiences

# %%
print(test[5].get_text())
# Out:
# Jack HarknessEleventh DoctorRiver SongAmy PondRory Williams

# %%
len(test)
# Out:
# 6

# %%
for x in range(len(test)):
    print(test[x].get_text().strip())
# Out:
# Teen And Up Audiences
# No Archive Warnings Apply
# Multi
# Doctor Who (2005)
# Eleventh Doctor/Jack Harkness/River SongAmy Pond/Rory Williams
# Jack HarknessEleventh DoctorRiver SongAmy PondRory Williams

# %%
test = results.get_text()
test
# Out:
# '\n\n\n\n\xa0\nSkip header\n\n\n\n\n\n\n\n\nActions\n\n\nComments \n\n\nShare\n\n\nDownload\n\nAZW3\nEPUB\nMOBI\nPDF\nHTML\n\n\n\n\nWork Header\n\n\n\n\n              Rating:\n          \n\n\nTeen And Up Audiences\n\n\n\nArchive Warning:\n          \n\n\nNo Archive Warnings Apply\n\n\n\n\n              Category:\n          \n\n\nMulti\n\n\n\n\n              Fandom:\n          \n\n\nDoctor Who (2005)\n\n\n\n\n              Relationships:\n          \n\n\nEleventh Doctor/Jack Harkness/River SongAmy Pond/Rory Williams\n\n\n\n\n              Characters:\n          \n\n\nJack HarknessEleventh DoctorRiver SongAmy PondRory Williams\n\n\n\n        Language:\n      \n\n        English\n      \n\n        Series:\n      \n\n← Previous Work Part 6 of the Jack and River totally know each other series\n\nStats:\n\n\nPublished:2012-08-16Words:1808Chapters:1/1Comments:2Kudos:61Bookmarks:2Hits:1373\n\n\n\n\n\n\n\n      All of time and space\n    \n\nLilithangel\n\n\nSummary:\n\nEarth has another immo
# ...

# %%
test = results.find_all('dd', class_ = 'language').html.contents
print(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-4dbd52ad8684> in <module>
# ----> 1 test = results.find_all('dd', class_ = 'language').html.contents
#       2 print(test)
#
# /opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in __getattr__(self, key)
#    2158     def __getattr__(self, key):
#    2159         """Raise a helpful exception to explain a common code fix."""
# -> 2160         raise AttributeError(
#    2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'html'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
<dd class="language">
    English
    
    dt class="series">
    Series:
   </dt>
   <dd class="series">
    <span class="series">
     <a class="previous" href="/works/487816">
      ← Previous Work
     </a>
     <span class="divider">
     </span>
     <span class="position">
      Part 6 of the
      <a href="/series/23883">
       Jack and River totally know each other
      </a>
      series
     </span>
    </span>
   </dd>


<dt class="stats">
    Stats:
   </dt>
   <dd class="stats">
    <!-- end of cache -->
    <dl class="stats">
     <dt class="published">
      Published:
     </dt>
     <dd class="published">
      2012-08-16
     </dd>
     <dt class="words">
      Words:
     </dt>
     <dd class="words">
      1808
     </dd>
     <dt class="chapters">
      Chapters:
     </dt>
     <dd class="chapters">
      1/1
     </dd>
     <dt class="comments">
      Comments:
     </dt>
     <dd class="comments">
      2
     </dd>
     <dt class="kudos">
      Kudos:
     </dt>
     <dd class="kudos">
      61
     </dd>
     <dt class="bookmarks">
      Bookmarks:
     </dt>
     <dd class="bookmarks">
      <a href="/works/487820/bookmarks">
       2
      </a>
     </dd>
     <dt class="hits">
      Hits:
     </dt>
     <dd class="hits">
      1373
     </dd>
        
        
<!-- BEGIN section where work skin applies -->
 <div id="workskin">
  <div class="preface group">
   <h2 class="title heading">
    All of time and space
   </h2>
   <h3 class="byline heading">
    <a href="/users/Lilithangel/pseuds/Lilithangel" rel="author">
     Lilithangel
    </a>
   </h3>
   <div class="summary module" role="complementary">
    <h3 class="heading">
     Summary:
    </h3>
    <blockquote class="userstuff">
     <p>
      Earth has another immortal defender so Jack buggers off and runs into River who brings him back to the Doctor. Amy and Rory learn to understand and not really cope with their daughter’s sex drive (or the Doctor’s come to that).
     </p>
    </blockquote>

# %%
print(results.prettify())
# Out:
# <div class="works-show region" id="main" role="main">
#  <div class="flash">
#  </div>
#  <!--page description, messages-->
#  <ul class="landmark skip">
#   <li>
#    <a name="top">
#    </a>
#   </li>
#   <li>
#    <a href="#work">
#     Skip header
#    </a>
#   </li>
#  </ul>
#  <!--/descriptions-->
#  <!--subnav-->
#  <!--/subnav-->
#  <!-- BEGIN revealed -->
#  <!-- BEGIN work -->
#  <!--work description, metadata, notes and messages-->
#  <!-- BEGIN navigation -->
#  <h3 class="landmark heading">
#   Actions
#  </h3>
#  <ul class="work navigation actions" role="menu">
#   <li class="comments" id="show_comments_link_top">
#    <a data-remote="true" href="/comments/show_comments?work_id=487820">
#     Comments
#    </a>
#   </li>
#   <li class="share hidden">
#    <a aria-controls="#modal" class="modal" href="/works/487820/share" title="Share Work">
#     Share
#    </a>
#   </li>
#   <li aria-haspopup="true" class="download">
#    <a href="#">
#     Download
#    </a>
# ...

# %% [markdown]
# Some notes:
#
# We can ignore the head section, everything we need is grabbable in the body.

# %% [markdown]
# <div class="wrapper" id="inner">
# <!-- BEGIN sidebar -->
# <!-- END sidebar -->
# <!-- BEGIN main -->
# <div class="works-show region" id="main" role="main">
# <div class="flash"></div>
# <!--page description, messages-->
# <ul class="landmark skip">
# <li><a name="top"> </a></li>
# <li><a href="#work">Skip header</a></li>
# </ul>
# <!--/descriptions-->
# <!--subnav-->
# <!--/subnav-->
# <!-- BEGIN revealed -->
# <!-- BEGIN work -->
# <!--work description, metadata, notes and messages-->
# <!-- BEGIN navigation -->
# <h3 class="landmark heading">Actions</h3>
# <ul class="work navigation actions" role="menu">
# <li class="comments" id="show_comments_link_top">
# <a data-remote="true" href="/comments/show_comments?work_id=487820">Comments </a>
# </li>
# <li class="share hidden">
# <a aria-controls="#modal" class="modal" href="/works/487820/share" title="Share Work">Share</a>
# </li>
# <li aria-haspopup="true" class="download">
# <a href="#">Download</a>
# <ul class="expandable secondary">
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.azw3?updated_at=1387518470">AZW3</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.epub?updated_at=1387518470">EPUB</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.mobi?updated_at=1387518470">MOBI</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.pdf?updated_at=1387518470">PDF</a></li>
# <li><a href="/downloads/487820/All%20of%20time%20and%20space.html?updated_at=1387518470">HTML</a></li>
# </ul>
# </li>
# </ul>
# <!-- END navigation -->
# <h3 class="landmark heading">Work Header</h3>
# <div class="wrapper">
# <dl class="work meta group" role="complementary">
# <dt class="rating tags">
#
#               Rating:
#           </dt>
# <dd class="rating tags">
# <ul class="commas">
# <li><a class="tag" href="/tags/Teen%20And%20Up%20Audiences/works">Teen And Up Audiences</a></li>
# </ul>
# </dd>
# <dt class="warning tags">
# <a href="/tos_faq#tags">Archive Warning</a>:
#           </dt>
# <dd class="warning tags">
# <ul class="commas">
# <li><a class="tag" href="/tags/No%20Archive%20Warnings%20Apply/works">No Archive Warnings Apply</a></li>
# </ul>
# </dd>
# <dt class="category tags">
#
#               Category:
#           </dt>
# <dd class="category tags">
# <ul class="commas">
# <li><a class="tag" href="/tags/Multi/works">Multi</a></li>
# </ul>
# </dd>
# <dt class="fandom tags">
#
#               Fandom:
#           </dt>
# <dd class="fandom tags">
# <ul class="commas">
# <li><a class="tag" href="/tags/Doctor%20Who%20(2005)/works">Doctor Who (2005)</a></li>
# </ul>
# </dd>
# <dt class="relationship tags">
#
#               Relationships:
#           </dt>
# <dd class="relationship tags">
# <ul class="commas">
# <li><a class="tag" href="/tags/Eleventh%20Doctor*s*Jack%20Harkness*s*River%20Song/works">Eleventh Doctor/Jack Harkness/River Song</a></li><li><a class="tag" href="/tags/Amy%20Pond*s*Rory%20Williams/works">Amy Pond/Rory Williams</a></li>
# </ul>
# </dd>
# <dt class="character tags">
#
#               Characters:
#           </dt>
# <dd class="character tags">
# <ul class="commas">
# <li><a class="tag" href="/tags/Jack%20Harkness/works">Jack Harkness</a></li><li><a class="tag" href="/tags/Eleventh%20Doctor/works">Eleventh Doctor</a></li><li><a class="tag" href="/tags/River%20Song/works">River Song</a></li><li><a class="tag" href="/tags/Amy%20Pond/works">Amy Pond</a></li><li><a class="tag" href="/tags/Rory%20Williams/works">Rory Williams</a></li>
# </ul>
# </dd>
# <dt class="language">
#         Language:
#       </dt>
# <dd class="language">
#         English
#       </dd>
# <dt class="series">
#         Series:
#       </dt>
# <dd class="series">
# <span class="series"><a class="previous" href="/works/487816">← Previous Work</a><span class="divider"> </span><span class="position">Part 6 of the <a href="/series/23883">Jack and River totally know each other</a> series</span></span>
# </dd>
# <dt class="stats">Stats:</dt>
# <dd class="stats">
# <!-- end of cache -->
# <dl class="stats"><dt class="published">Published:</dt><dd class="published">2012-08-16</dd><dt class="words">Words:</dt><dd class="words">1808</dd><dt class="chapters">Chapters:</dt><dd class="chapters">1/1</dd><dt class="comments">Comments:</dt><dd class="comments">2</dd><dt class="kudos">Kudos:</dt><dd class="kudos">61</dd><dt class="bookmarks">Bookmarks:</dt><dd class="bookmarks"><a href="/works/487820/bookmarks">2</a></dd><dt class="hits">Hits:</dt><dd class="hits">1373</dd></dl>
# </dd>
# </dl>
# </div>
# <!-- BEGIN section where work skin applies -->
# <div id="workskin">
# <div class="preface group">
# <h2 class="title heading">
#       All of time and space
#     </h2>
# <h3 class="byline heading">
# <a href="/users/Lilithangel/pseuds/Lilithangel" rel="author">Lilithangel</a>
# </h3>
# <div class="summary module" role="complementary">
# <h3 class="heading">Summary:</h3>
# <blockquote class="userstuff">
# <p>Earth has another immortal defender so Jack buggers off and runs into River who brings him back to the Doctor. Amy and Rory learn to understand and not really cope with their daughter’s sex drive (or the Doctor’s come to that).</p>
# </blockquote>
# </div>
# <div class="notes module" role="complementary">
# <h3 class="heading">Notes:</h3>
# <p class="jump">(See the end of the work for <a href="#work_endnotes">notes</a>.)</p>
# </div>
# </div>
